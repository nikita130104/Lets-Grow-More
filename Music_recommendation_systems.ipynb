# %% [markdown]
# <a href="https://colab.research.google.com/github/nikita130104/Lets-Grow-More/blob/main/Music_recommendation_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# !cp /content/drive/MyDrive/Recommenders.py /content
import Recommenders as Recommenders

# %%
df_song_1 = pd.read_csv('/content/triplets_file.csv')
df_song_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0

# %%
df_song_1.isna().sum()
# Out:
# user_id         0
# song_id         0
# listen_count    1
# dtype: int64

# %%
df_song_2 = pd.read_csv('/content/song_data.csv')
df_song_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
len(df_song_2)
# Out:
# 26791

# %%
df_song_2.isna().sum()
# Out:
# song_id        0
# title          0
# release        0
# artist_name    0
# year           1
# dtype: int64

# %%
df_song = pd.merge(df_song_1,df_song_2.drop_duplicates(['song_id']),how ='left')
df_song.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title              release    artist_name    year
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2              NaN                  NaN            NaN     NaN
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN

# %%
len(df_song)
# Out:
# 249433

# %%
df_song['song_details'] = df_song['title']+' - '+df_song['artist_name']
df_song.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title              release    artist_name    year  \
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2              NaN                  NaN            NaN     NaN
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN
#
#                       song_details
# 0                              NaN
# 1  Entre Dos Aguas - Paco De Lucia
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
grouped_song_details = df_song.groupby(['song_details']).agg({'listen_count':'count'})
grouped_song_details.head()
# Out:
#                                          listen_count
# song_details
# (Anaesthesia) Pulling Teath - Metallica             9
# A Dream - Cut Copy                                 22
# A Dream - Rebecka Törnqvist                        32
# A Kind Of Hope - Pilot Speed                        9
# Addicted - Amy Winehouse                           31

# %%
PR = Recommenders.popularity_recommender_py()

# %%
PR.create(df_song, 'user_id', 'song_details')

# %%
PR.recommend(df_song['user_id'][6])
# Out:
#                                       user_id  \
# 203  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 160  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 280  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 191  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 59   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 247  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 145  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 237  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 168  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 174  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                           song_details  score  Rank
# 203            Sincerité Et Jalousie - Alliance Ethnik    388   1.0
# 160  Nothin' On You [feat. Bruno Mars] (Album Versi...    261   2.0
# 280       You've Got The Love - Florence + The Machine    249   3.0
# 191                               Rock Star - N.E.R.D.    211   4.0
# 59      Eenie Meenie - Sean Kingston and Justin Bieber    199   5.0
# 247                             Toxic - Britney Spears    163   6.0
# 145                                Nah! - Shania Twain    145   7.0
# 237                         The Maestro - Beastie Boys    141   8.0
# 168                                    One - Metallica    106   9.0
# 174                           Patience - Guns N' Roses    103  10.0

# %%
PR.recommend(df_song['user_id'][17])
# Out:
#                                       user_id  \
# 203  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 160  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 280  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 191  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 59   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 247  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 145  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 237  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 168  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 174  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                           song_details  score  Rank
# 203            Sincerité Et Jalousie - Alliance Ethnik    388   1.0
# 160  Nothin' On You [feat. Bruno Mars] (Album Versi...    261   2.0
# 280       You've Got The Love - Florence + The Machine    249   3.0
# 191                               Rock Star - N.E.R.D.    211   4.0
# 59      Eenie Meenie - Sean Kingston and Justin Bieber    199   5.0
# 247                             Toxic - Britney Spears    163   6.0
# 145                                Nah! - Shania Twain    145   7.0
# 237                         The Maestro - Beastie Boys    141   8.0
# 168                                    One - Metallica    106   9.0
# 174                           Patience - Guns N' Roses    103  10.0

# %%
IR = Recommenders.item_similarity_recommender_py()
IR.create(df_song, 'user_id', 'song_details')

# %%
user_fav_items = IR.get_user_items(df_song['user_id'][10])

# %%
for user_fav_item in user_fav_items:
    print(user_fav_item)
# Out:
# nan

# %%
user_fav_items = IR.get_user_items(df_song['user_id'][100])

# %%
for user_fav_item in user_fav_items:
    print(user_fav_item)
# Out:
# nan

# %%
IR.recommend(df_song['user_id'][100])
# Out:
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 285
# Non zero values in cooccurence_matrix :0
#                                     user_id  \
# 0  e006b1a48f466bf59feefed32bec6494495a4436
# 1  e006b1a48f466bf59feefed32bec6494495a4436
# 2  e006b1a48f466bf59feefed32bec6494495a4436
# 3  e006b1a48f466bf59feefed32bec6494495a4436
# 4  e006b1a48f466bf59feefed32bec6494495a4436
# 5  e006b1a48f466bf59feefed32bec6494495a4436
# 6  e006b1a48f466bf59feefed32bec6494495a4436
# 7  e006b1a48f466bf59feefed32bec6494495a4436
# 8  e006b1a48f466bf59feefed32bec6494495a4436
# 9  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                 song  score  rank
# 0                          Blue Eyes - Cary Brothers    0.0     1
# 1                You're In My Heart - Rhonda Vincent    0.0     2
# 2                 Darlin' Do Not Fear - Brett Dennen    0.0     3
# 3         Great Dub In The Sky - Easy Star All-Stars    0.0     4
# 4                           La Niña - Mala Rodriguez    0.0     5
# 5                 Curs in the Weeds - Horse Feathers    0.0     6
# 6                                   Intro - Gorillaz    0.0     7
# 7                      Synchronicity II - The Police    0.0     8
# 8               Rebel Without A Pause - Public Enemy    0.0     9
# 9  Happy (Love Theme From "Lady Sings The Blues")...    0.0    10

# %%
IR.get_similar_items(['Somebody To Love - Justin Bieber'])
# Out:
# no. of unique songs in the training set: 285
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                  Blue Eyes - Cary Brothers    0.0     1
# 1                        You're In My Heart - Rhonda Vincent    0.0     2
# 2                         Darlin' Do Not Fear - Brett Dennen    0.0     3
# 3                 Great Dub In The Sky - Easy Star All-Stars    0.0     4
# 4                                   La Niña - Mala Rodriguez    0.0     5
# 5                         Curs in the Weeds - Horse Feathers    0.0     6
# 6                                           Intro - Gorillaz    0.0     7
# 7                              Synchronicity II - The Police    0.0     8
# 8                       Rebel Without A Pause - Public Enemy    0.0     9
# 9          Happy (Love Theme From "Lady Sings The Blues")...    0.0    10

# %%
IR.get_similar_items(['The Scientist - Coldplay'])
# Out:
# no. of unique songs in the training set: 285
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                  Blue Eyes - Cary Brothers    0.0     1
# 1                        You're In My Heart - Rhonda Vincent    0.0     2
# 2                         Darlin' Do Not Fear - Brett Dennen    0.0     3
# 3                 Great Dub In The Sky - Easy Star All-Stars    0.0     4
# 4                                   La Niña - Mala Rodriguez    0.0     5
# 5                         Curs in the Weeds - Horse Feathers    0.0     6
# 6                                           Intro - Gorillaz    0.0     7
# 7                              Synchronicity II - The Police    0.0     8
# 8                       Rebel Without A Pause - Public Enemy    0.0     9
# 9          Happy (Love Theme From "Lady Sings The Blues")...    0.0    10
